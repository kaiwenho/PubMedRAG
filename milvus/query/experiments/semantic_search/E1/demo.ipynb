# %%
from biomed_eval import BiomedicalRetrievalEvaluator

data_path = 'intermedia_data/gold_df.pkl'

# %%
evaluator = BiomedicalRetrievalEvaluator(data_path, predicate='biolink:treats')
evaluator.check_embedding_cache_status()
# Out:
# Loaded 1778 edges total
# After excluding 'maybe': 1432 edges
# After filtering for predicate 'biolink:treats': 375 edges
# Label distribution:
# abstract_support?
# yes    200
# no     175
# Name: count, dtype: int64
#
# ============================================================
# EMBEDDING CACHE STATUS
# ============================================================
#
# concat_general:
#   Cached examples: 742
#   Cache size: 11.30 MB
#
# concat_biomedical:
#   Cached examples: 742
#   Cache size: 22.33 MB
#
# ai_general:
#   Cached examples: 742
#   Cache size: 11.30 MB
#
# ai_biomedical:
#   Cached examples: 742
#   Cache size: 22.32 MB
#
# ============================================================
# TOTAL:
#   Cached examples: 2968
#   Total cache size: 67.25 MB
# ============================================================

# %%
evaluator.split_data()
# evaluator.precompute_all_embeddings()
evaluator.run_validation_pipeline() 
test_result = evaluator.run_test_evaluation()
# Out:
# Splitting data into validation/test by predicate and label...
# Found 1 unique predicates: ['biolink:treats']
#   biolink:treats + yes: 100 val, 100 test
#   biolink:treats + no: 88 val, 87 test
#
# ============================================================
# Final split sizes:
#   val: 188 edges
#     Labels: {'yes': 100, 'no': 88}
#     Predicates: {'biolink:treats': 188}
#   test: 187 edges
#     Labels: {'yes': 100, 'no': 87}
#     Predicates: {'biolink:treats': 187}
# ============================================================
#
# ============================================================
# VALIDATION PHASE: Comparing configurations
# ============================================================
# Filtered by predicate: 'biolink:treats'
#
# --- Configuration: concat_general ---
#
# Computing similarities: concat + general
#   Checking embedding cache: concat + general
#   ✓ Embeddings: 188 from cache, 0 newly computed
# Best aggregation: max (PR-AUC: 0.8281)
#   Optimal threshold: 0.6082
#     Precision: 0.7802
#     Recall: 0.7100
#
# --- Configuration: concat_biomedical ---
#
# Computing similarities: concat + biomedical
#   Checking embedding cache: concat + biomedical
#   ✓ Embeddings: 188 from cache, 0 newly computed
# Best aggregation: max (PR-AUC: 0.7796)
#   Optimal threshold: 0.5381
#     Precision: 0.7245
#     Recall: 0.7100
#
# --- Configuration: ai_general ---
#
# Computing similarities: ai + general
#   Checking embedding cache: ai + general
#   ✓ Embeddings: 188 from cache, 0 newly computed
# Best aggregation: max (PR-AUC: 0.8215)
#   Optimal threshold: 0.6473
#     Precision: 0.7526
#     Recall: 0.7300
#
# --- Configuration: ai_biomedical ---
#
# Computing similarities: ai + biomedical
#   Checking embedding cache: ai + biomedical
#   ✓ Embeddings: 188 from cache, 0 newly computed
# Best aggregation: max (PR-AUC: 0.7997)
#   Optimal threshold: 0.5735
#     Precision: 0.7143
#     Recall: 0.7000
#
# ============================================================
# VALIDATION RESULTS COMPARISON
# ============================================================
#
# Sentence-Level Metrics:
#     Configuration      MRR  Recall@1  Recall@3  Recall@5  Sent-AUC-PR
#        ai_general 0.915833  0.649167  0.875833  0.942500     0.611041
#    concat_general 0.907833  0.629167  0.865833  0.932500     0.603902
#     ai_biomedical 0.886262  0.614167  0.840833  0.930000     0.626284
# concat_biomedical 0.872595  0.580833  0.844167  0.929167     0.621028
#
# Abstract-Level Metrics:
#     Configuration Best Agg  Abs-PR-AUC  Abs-ROC-AUC  Threshold
#        ai_general      max    0.821451     0.782500   0.647278
#    concat_general      max    0.828090     0.799545   0.608183
#     ai_biomedical      max    0.799678     0.768523   0.573543
# concat_biomedical      max    0.779609     0.766477   0.538095
#
# ============================================================
# BEST CONFIGURATION: ai_general
#   Combined Score (MRR + Abs-PR-AUC): 1.7373
# ============================================================
#
# ============================================================
# TEST PHASE: Final evaluation with frozen configuration
# ============================================================
# Filtered by predicate: 'biolink:treats'
# Configuration: ai_general
#   Representation: ai
#   Model: general
#   Aggregation: max
#   Threshold: 0.6473
#
# Computing similarities: ai + general
#   Checking embedding cache: ai + general
#   ✓ Embeddings: 187 from cache, 0 newly computed
#
# Sentence-level metrics:
#   MRR: 0.8856
#   mean_rank: 1.4100
#   recall_at_k_1: 0.6167
#   recall_at_k_3: 0.8492
#   recall_at_k_5: 0.9250
#   AUC_ROC: 0.8566
#   AUC_PR: 0.5932
#
# Abstract-level metrics:
#   ROC-AUC: 0.7215
#   PR-AUC: 0.7435
#
# Classification at threshold 0.6473:
#   precision: 0.6869
#   recall: 0.6800
#   f1: 0.6834
#
# Bootstrap 95% CIs (1000 iterations):
#   Running 1000 bootstrap iterations...
#     200/1000 iterations complete
#     400/1000 iterations complete
#     600/1000 iterations complete
#     800/1000 iterations complete
#     1000/1000 iterations complete
#   MRR: [0.8360, 0.9352]
#   PR-AUC: [0.6545, 0.8267]

# %%
evaluator.save_results(filepath='evaluation_results.json')
# Out:
# ============================================================
# DETERMINING BEST SENTENCE-LEVEL THRESHOLD
# ============================================================
#
# Analyzing AI + General:
#
# ============================================================
# SENTENCE-LEVEL THRESHOLD ANALYSIS
# ============================================================
# Purpose: Find optimal similarity threshold for vector search filtering
# Filtered by predicate: 'biolink:treats'
#
# Using configuration: ai_general
#
# ============================================================
# RECOMMENDED MILVUS PARAMETERS:
# ============================================================
#
# For Milvus range search with COSINE metric:
#   (Returns entities with similarity in [radius, range_filter])
#
#   For BALANCED (Max F1):
#     radius: 0.6500
#     range_filter: 1.0
#     → Precision: 0.4393, Recall: 0.4691, F1: 0.4537
#
# ============================================================
#
# Analyzing Concat + General:
#
# ============================================================
# SENTENCE-LEVEL THRESHOLD ANALYSIS
# ============================================================
# Purpose: Find optimal similarity threshold for vector search filtering
# Filtered by predicate: 'biolink:treats'
#
# Using configuration: concat_general
#   Recomputing similarities for requested configuration...
#
# Computing similarities: concat + general
#   Checking embedding cache: concat + general
#   ✓ Embeddings: 187 from cache, 0 newly computed
#
# ============================================================
# RECOMMENDED MILVUS PARAMETERS:
# ============================================================
#
# For Milvus range search with COSINE metric:
#   (Returns entities with similarity in [radius, range_filter])
#
#   For BALANCED (Max F1):
#     radius: 0.6000
#     range_filter: 1.0
#     → Precision: 0.3937, Recall: 0.5370, F1: 0.4543
#
# ============================================================
#
# ============================================================
# COMPARISON:
# ============================================================
# AI + General:
#   Threshold: 0.6500
#   F1: 0.4537, Precision: 0.4393, Recall: 0.4691
#
# Concat + General:
#   Threshold: 0.6000
#   F1: 0.4543, Precision: 0.3937, Recall: 0.5370
#
# ============================================================
# SELECTED: CONCAT + GENERAL
# ============================================================
#
# Creating new evaluation history file
#
# Appending new record for predicate 'biolink:treats', n_examples=375
#
# Results saved to: evaluation_results.json
# Total evaluations in history: 1
# Predicates with latest parameters: ['biolink:treats']

# %%
evaluator = BiomedicalRetrievalEvaluator(data_path, predicate='biolink:affects')
# evaluator.check_embedding_cache_status()
evaluator.split_data()
# evaluator.precompute_all_embeddings()
validation_result = evaluator.run_validation_pipeline()
test_result = evaluator.run_test_evaluation()
evaluator.save_results(filepath='evaluation_results.json')
# Out:
# Loaded 1778 edges total
# After excluding 'maybe': 1432 edges
# After filtering for predicate 'biolink:affects': 367 edges
# Label distribution:
# abstract_support?
# no     184
# yes    183
# Name: count, dtype: int64
#
# Splitting data into validation/test by predicate and label...
# Found 1 unique predicates: ['biolink:affects']
#   biolink:affects + yes: 92 val, 91 test
#   biolink:affects + no: 92 val, 92 test
#
# ============================================================
# Final split sizes:
#   val: 184 edges
#     Labels: {'yes': 92, 'no': 92}
#     Predicates: {'biolink:affects': 184}
#   test: 183 edges
#     Labels: {'no': 92, 'yes': 91}
#     Predicates: {'biolink:affects': 183}
# ============================================================
#
# ============================================================
# VALIDATION PHASE: Comparing configurations
# ============================================================
# Filtered by predicate: 'biolink:affects'
#
# --- Configuration: concat_general ---
#
# Computing similarities: concat + general
#   Checking embedding cache: concat + general
#   ✓ Embeddings: 184 from cache, 0 newly computed
# Best aggregation: max (PR-AUC: 0.7213)
#   Optimal threshold: 0.4246
#     Precision: 0.6283
#     Recall: 0.7717
#
# --- Configuration: concat_biomedical ---
#
# Computing similarities: concat + biomedical
#   Checking embedding cache: concat + biomedical
#   ✓ Embeddings: 184 from cache, 0 newly computed
# Best aggregation: top3_mean (PR-AUC: 0.7562)
#   Optimal threshold: 0.3405
#     Precision: 0.6226
#     Recall: 0.7174
#
# --- Configuration: ai_general ---
#
# Computing similarities: ai + general
#   Checking embedding cache: ai + general
#   ✓ Embeddings: 184 from cache, 0 newly computed
# Best aggregation: top2_mean (PR-AUC: 0.7633)
#   Optimal threshold: 0.5474
#     Precision: 0.6915
#     Recall: 0.7065
#
# --- Configuration: ai_biomedical ---
#
# Computing similarities: ai + biomedical
#   Checking embedding cache: ai + biomedical
#   ✓ Embeddings: 184 from cache, 0 newly computed
# Best aggregation: top3_mean (PR-AUC: 0.7345)
#   Optimal threshold: 0.4364
#     Precision: 0.6415
#     Recall: 0.7391
#
# ============================================================
# VALIDATION RESULTS COMPARISON
# ============================================================
#
# Sentence-Level Metrics:
#     Configuration      MRR  Recall@1  Recall@3  Recall@5  Sent-AUC-PR
#    concat_general 0.703209  0.354167  0.669384  0.861413     0.379049
#        ai_general 0.687905  0.334239  0.675725  0.834239     0.354226
#     ai_biomedical 0.681180  0.317935  0.656703  0.886775     0.353632
# concat_biomedical 0.637715  0.276268  0.627717  0.840580     0.326587
#
# Abstract-Level Metrics:
#     Configuration  Best Agg  Abs-PR-AUC  Abs-ROC-AUC  Threshold
#    concat_general       max    0.721305     0.724008   0.424583
#        ai_general top2_mean    0.763312     0.777765   0.547408
#     ai_biomedical top3_mean    0.734486     0.750473   0.436378
# concat_biomedical top3_mean    0.756194     0.741257   0.340474
#
# ============================================================
# BEST CONFIGURATION: ai_general
#   Combined Score (MRR + Abs-PR-AUC): 1.4512
# ============================================================
#
# ============================================================
# TEST PHASE: Final evaluation with frozen configuration
# ============================================================
# Filtered by predicate: 'biolink:affects'
# Configuration: ai_general
#   Representation: ai
#   Model: general
#   Aggregation: top2_mean
#   Threshold: 0.5474
#
# Computing similarities: ai + general
#   Checking embedding cache: ai + general
#   ✓ Embeddings: 183 from cache, 0 newly computed
#
# Sentence-level metrics:
#   MRR: 0.6523
#   mean_rank: 2.2308
#   recall_at_k_1: 0.3123
#   recall_at_k_3: 0.6639
#   recall_at_k_5: 0.8507
#   AUC_ROC: 0.7101
#   AUC_PR: 0.3422
#
# Abstract-level metrics:
#   ROC-AUC: 0.8116
#   PR-AUC: 0.7682
#
# Classification at threshold 0.5474:
#   precision: 0.7426
#   recall: 0.8242
#   f1: 0.7812
#
# Bootstrap 95% CIs (1000 iterations):
#   Running 1000 bootstrap iterations...
#     200/1000 iterations complete
#     400/1000 iterations complete
#     600/1000 iterations complete
#     800/1000 iterations complete
#     1000/1000 iterations complete
#   MRR: [0.5889, 0.7228]
#   PR-AUC: [0.6703, 0.8690]
#
# ============================================================
# DETERMINING BEST SENTENCE-LEVEL THRESHOLD
# ============================================================
#
# Analyzing AI + General:
#
# ============================================================
# SENTENCE-LEVEL THRESHOLD ANALYSIS
# ============================================================
# Purpose: Find optimal similarity threshold for vector search filtering
# Filtered by predicate: 'biolink:affects'
#
# Using configuration: ai_general
#
# ============================================================
# RECOMMENDED MILVUS PARAMETERS:
# ============================================================
#
# For Milvus range search with COSINE metric:
#   (Returns entities with similarity in [radius, range_filter])
#
#   For BALANCED (Max F1):
#     radius: 0.5500
#     range_filter: 1.0
#     → Precision: 0.2528, Recall: 0.5723, F1: 0.3507
#
# ============================================================
#
# Analyzing Concat + General:
#
# ============================================================
# SENTENCE-LEVEL THRESHOLD ANALYSIS
# ============================================================
# Purpose: Find optimal similarity threshold for vector search filtering
# Filtered by predicate: 'biolink:affects'
#
# Using configuration: concat_general
#   Recomputing similarities for requested configuration...
#
# Computing similarities: concat + general
#   Checking embedding cache: concat + general
#   ✓ Embeddings: 183 from cache, 0 newly computed
#
# ============================================================
# RECOMMENDED MILVUS PARAMETERS:
# ============================================================
#
# For Milvus range search with COSINE metric:
#   (Returns entities with similarity in [radius, range_filter])
#
#   For BALANCED (Max F1):
#     radius: 0.4000
#     range_filter: 1.0
#     → Precision: 0.2008, Recall: 0.6667, F1: 0.3086
#
# ============================================================
#
# ============================================================
# COMPARISON:
# ============================================================
# AI + General:
#   Threshold: 0.5500
#   F1: 0.3507, Precision: 0.2528, Recall: 0.5723
#
# Concat + General:
#   Threshold: 0.4000
#   F1: 0.3086, Precision: 0.2008, Recall: 0.6667
#
# ============================================================
# SELECTED: AI + GENERAL
# ============================================================
#
# Appending new record for predicate 'biolink:affects', n_examples=367
#
# Results saved to: evaluation_results.json
# Total evaluations in history: 2
# Predicates with latest parameters: ['biolink:affects', 'biolink:treats']

# %%
# Option 1: Get all predicates' parameters
all_params = evaluator.get_latest_parameters('evaluation_results.json')
# Out:
# Loaded evaluation history from: evaluation_results.json
# Total evaluations: 2
#
# ============================================================
# LATEST PARAMETERS FOR ALL PREDICATES
# ============================================================
#
# biolink:affects:
#   Updated: 2025-10-21T15:31:13.141028
#   N examples: 367
#   Sentence threshold: 0.550 (ai + general)
#   Abstract threshold: 0.547 (ai + top2_mean)
#   Test MRR: 0.652, PR-AUC: 0.768
#
# biolink:treats:
#   Updated: 2025-10-21T15:31:05.380874
#   N examples: 375
#   Sentence threshold: 0.600 (concat + general)
#   Abstract threshold: 0.647 (ai + max)
#   Test MRR: 0.886, PR-AUC: 0.743
# ============================================================

# %%
# Option 2: Get specific predicate's parameters
treats_params = evaluator.get_latest_parameters(
    'evaluation_results.json', 
    predicate='biolink:treats'
)
# Out:
# Loaded evaluation history from: evaluation_results.json
# Total evaluations: 2
#
# ============================================================
# LATEST PARAMETERS FOR PREDICATE: 'biolink:treats'
# ============================================================
# Timestamp: 2025-10-21T15:31:05.380874
# Based on 375 examples (188 val, 187 test)
#
# Sentence-Level Search:
#   Model: sentence-transformers/all-MiniLM-L6-v2
#   Representation: concat
#   Threshold: 0.600
#   Expected F1: 0.454
#   Expected Precision: 0.394
#   Expected Recall: 0.537
#
# Abstract-Level Classification:
#   Model: sentence-transformers/all-MiniLM-L6-v2
#   Representation: ai
#   Aggregation: max
#   Threshold: 0.647
#
# Test Performance:
#   MRR: 0.886
#   Recall@3: 0.849
#   PR-AUC: 0.743
#   Classification F1: 0.683
# ============================================================
